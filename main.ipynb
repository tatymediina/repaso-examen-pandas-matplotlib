# %% [markdown]
# # Limpieza y Visualización de Datos con Pandas y Matplotlib
#
# Para esto, debemos realizar lo siguiente:
#
# 1. Cargar y explorar un dataset.
#
# 2. Aplicar técnicas de limpieza usando pandas.
#
# 3. Convertir datos (fechas, números, categorías).
#
# 4. Visualizar los datos limpios con matplotlib para obtener insights.

# %% [markdown]
# ### Requerimientos:
# 1. Entorno Virtual.
# 2. Datasets.
# 3. Librerias: Pandas, sqlite3, Matplotlib.

# %% [markdown]
# **Para realizar esto, debemos instalar las siguientes dependencias**

# %%
pip install pandas matplotlib

# %% [markdown]
# ## Extración de datos con Pandas
# Vamos a utilizar pandas para leer nuestro csv

# %%
# importar librerías
import pandas as pd
import matplotlib as plt

# %% [markdown]
# **Creamos nuestro DF**
#
# En el caso de que nos de un error de decodificación, podriamos utilizar el encoding "ISO-8859-1"

# %%
df= pd.read_csv('datasets.csv', on_bad_lines="skip") # ! si tiene errores en la fila se las saltea
df.head()
# Out:
#        Nombre Edad                Email Fecha_Registro Ingresos Genero  \
# 0   Juan Prez   29      juanperez@gmail     2021-03-15   $3,000      M
# 1   Mara Lpez  NaN  m.lopez@outlook.com     15/04/2021     4000      F
# 2  jose lopez  NaN           joselopez@     2021/05/20  3500.00      M
# 3    Ana Gmez   31  ana_gomez@gmail.com     2021-06-01      NaN      f
# 4   Juan Prez   29      juanperez@gmail     2021-03-15   $3,000      M
#
#           Comentario
# 0  Cliente frecuente
# 1  Cliente Frecuente
# 2                NaN
# 3                NaN
# 4  Cliente frecuente

# %% [markdown]
# ### Explorar el datasets
# Ahora debemos utilizar funciones de pandas para poder explorar los tipos de datos que tenemos y obviamente ver si tenemos datos nulos o inservibles.

# %%
df.dtypes
# Out:
# Nombre            object
# Edad              object
# Email             object
# Fecha_Registro    object
# Ingresos          object
# Genero            object
# Comentario        object
# dtype: object

# %%
df.isnull().sum()

# %% [markdown]
# # Limpieza de Datos
# 3. **Conversión de Tipos y Estandarización**
#
# * Edad: Convertir a numérico, usando errors="coerce" para transformar valores inválidos en NaN.
#
# * Fecha_Registro: Convertir las fechas a formato datetime.
#
# * Ingresos: Remover símbolos y convertir a numérico.
#
# * Genero: Estandarizar los valores ("MASCULINO" o "m" a "M", "FEMENINO" o "f" a "F").
#
# * Nombres: Corregir la capitalización y quitar espacios extras.

# %% [markdown]
# ### Convertir Edad a numérico
# Edad: Convertir a numérico con to_numeric() usando errors="coerce" para transformar valores inválidos en NaN.

# %%
# Convertir Edad a numérico
df["Edad"] = pd.to_numeric(df["Edad"], errors="coerce")
df.head(10)
# Out:
#            Nombre  Edad                Email Fecha_Registro       Ingresos  \
# 0       Juan Prez  29.0      juanperez@gmail     2021-03-15         $3,000
# 1       Mara Lpez   NaN  m.lopez@outlook.com     15/04/2021           4000
# 2      jose lopez   NaN           joselopez@     2021/05/20        3500.00
# 3        Ana Gmez  31.0  ana_gomez@gmail.com     2021-06-01            NaN
# 4       Juan Prez  29.0      juanperez@gmail     2021-03-15         $3,000
# 5             NaN  45.0                  NaN     2021-07-12        5000.50
# 6    Lucas Torres  27.0   lucastorres@correo     2021-08-01           4800
# 7       Mara Lpez  30.0  m.lopez@outlook.com     2021-04-15           4000
# 8  Laura Fernndez  26.0     laura@correo.com     2021-09-01  not available
# 9        Jos Lpez  30.0  joselopez@gmail.com     2021-10-10          3.600
#
#       Genero         Comentario
# 0          M  Cliente frecuente
# 1          F  Cliente Frecuente
# 2          M                NaN
# 3          f                NaN
# 4          M  Cliente frecuente
# 5          M                NaN
# 6  MASCULINO        Cliente VIP
# 7          F                NaN
# 8          F      Cliente nuevo
# 9          M                NaN

# %% [markdown]
# ### Convertir Fecha_Registro a datetime

# %%
# Convertir Fecha_Registro a datetime (detecta errores y asigna NaT)
df["Fecha_Registro"]= pd.to_datetime(df["Fecha_Registro"], errors="coerce")
df.head(10)
# Out:
#            Nombre  Edad                Email Fecha_Registro       Ingresos  \
# 0       Juan Prez  29.0      juanperez@gmail     2021-03-15         $3,000
# 1       Mara Lpez   NaN  m.lopez@outlook.com            NaT           4000
# 2      jose lopez   NaN           joselopez@            NaT        3500.00
# 3        Ana Gmez  31.0  ana_gomez@gmail.com     2021-06-01            NaN
# 4       Juan Prez  29.0      juanperez@gmail     2021-03-15         $3,000
# 5             NaN  45.0                  NaN     2021-07-12        5000.50
# 6    Lucas Torres  27.0   lucastorres@correo     2021-08-01           4800
# 7       Mara Lpez  30.0  m.lopez@outlook.com     2021-04-15           4000
# 8  Laura Fernndez  26.0     laura@correo.com     2021-09-01  not available
# 9        Jos Lpez  30.0  joselopez@gmail.com     2021-10-10          3.600
#
#       Genero         Comentario
# 0          M  Cliente frecuente
# 1          F  Cliente Frecuente
# 2          M                NaN
# 3          f                NaN
# 4          M  Cliente frecuente
# 5          M                NaN
# 6  MASCULINO        Cliente VIP
# 7          F                NaN
# 8          F      Cliente nuevo
# 9          M                NaN

# %% [markdown]
# ### Limpiar columna de ingresos
# Para ello, esta vez utilizaremos el siguiente REGEX
# * "[\$,]", "", regex=True

# %%
df["Ingresos"]  = df["Ingresos"].replace("[\$,]", "", regex=True)
df["Ingresos"] = pd.to_numeric(df["Ingresos"], errors="coerce")
df.head(10)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\IPF-2025\AppData\Local\Temp\ipykernel_8196\3756308580.py:1: SyntaxWarning: invalid escape sequence '\$'
#   df["Ingresos"]  = df["Ingresos"].replace("[\$,]", "", regex=True)
#            Nombre  Edad                Email Fecha_Registro  Ingresos  \
# 0       Juan Prez  29.0      juanperez@gmail     2021-03-15    3000.0
# 1       Mara Lpez   NaN  m.lopez@outlook.com            NaT    4000.0
# 2      jose lopez   NaN           joselopez@            NaT    3500.0
# 3        Ana Gmez  31.0  ana_gomez@gmail.com     2021-06-01       NaN
# 4       Juan Prez  29.0      juanperez@gmail     2021-03-15    3000.0
# 5             NaN  45.0                  NaN     2021-07-12    5000.5
# 6    Lucas Torres  27.0   lucastorres@correo     2021-08-01    4800.0
# 7       Mara Lpez  30.0  m.lopez@outlook.com     2021-04-15    4000.0
# 8  Laura Fernndez  26.0     laura@correo.com     2021-09-01       NaN
# 9        Jos Lpez  30.0  joselopez@gmail.com     2021-10-10       3.6
#
#       Genero         Comentario
# 0          M  Cliente frecuente
# 1          F  Cliente Frecuente
# 2          M                NaN
# 3          f                NaN
# 4          M  Cliente frecuente
# 5          M                NaN
# 6  MASCULINO        Cliente VIP
# 7          F                NaN
# 8          F      Cliente nuevo
# 9          M                NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Nombre          47 non-null     object
#  1   Edad            32 non-null     float64
#  2   Email           41 non-null     object
#  3   Fecha_Registro  32 non-null     datetime64[ns]
#  4   Ingresos        32 non-null     float64
#  5   Genero          44 non-null     object
#  6   Comentario      24 non-null     object
# dtypes: datetime64[ns](1), float64(2), object(4)
# memory usage: 2.8+ KB

# %% [markdown]
# ### Estandarizar Género
# Estandarizar los valores ("MASCULINO" o "m" a "M", "FEMENINO" o "f" a "F").

# %%
df["Genero"] = df["Genero"].str.upper().str.strip()
df.head(10)
# Out:
#            Nombre  Edad                Email Fecha_Registro  Ingresos  \
# 0       Juan Prez  29.0      juanperez@gmail     2021-03-15    3000.0
# 1       Mara Lpez   NaN  m.lopez@outlook.com            NaT    4000.0
# 2      jose lopez   NaN           joselopez@            NaT    3500.0
# 3        Ana Gmez  31.0  ana_gomez@gmail.com     2021-06-01       NaN
# 4       Juan Prez  29.0      juanperez@gmail     2021-03-15    3000.0
# 5             NaN  45.0                  NaN     2021-07-12    5000.5
# 6    Lucas Torres  27.0   lucastorres@correo     2021-08-01    4800.0
# 7       Mara Lpez  30.0  m.lopez@outlook.com     2021-04-15    4000.0
# 8  Laura Fernndez  26.0     laura@correo.com     2021-09-01       NaN
# 9        Jos Lpez  30.0  joselopez@gmail.com     2021-10-10       3.6
#
#       Genero         Comentario
# 0          M  Cliente frecuente
# 1          F  Cliente Frecuente
# 2          M                NaN
# 3          F                NaN
# 4          M  Cliente frecuente
# 5          M                NaN
# 6  MASCULINO        Cliente VIP
# 7          F                NaN
# 8          F      Cliente nuevo
# 9          M                NaN

# %%
df["Genero"] = df["Genero"].replace("MASCULINO", "F").replace("FEMENINO", "F")
df.head(20)
# Out:
#             Nombre  Edad                Email Fecha_Registro  Ingresos Genero  \
# 0        Juan Prez  29.0      juanperez@gmail     2021-03-15    3000.0      M
# 1        Mara Lpez   NaN  m.lopez@outlook.com            NaT    4000.0      F
# 2       jose lopez   NaN           joselopez@            NaT    3500.0      M
# 3         Ana Gmez  31.0  ana_gomez@gmail.com     2021-06-01       NaN      F
# 4        Juan Prez  29.0      juanperez@gmail     2021-03-15    3000.0      M
# 5              NaN  45.0                  NaN     2021-07-12    5000.5      M
# 6     Lucas Torres  27.0   lucastorres@correo     2021-08-01    4800.0      F
# 7        Mara Lpez  30.0  m.lopez@outlook.com     2021-04-15    4000.0      F
# 8   Laura Fernndez  26.0     laura@correo.com     2021-09-01       NaN      F
# 9         Jos Lpez  30.0  joselopez@gmail.com     2021-10-10       3.6      M
# 10      Carlos Daz   NaN           carlos123@            NaT    4000.0      M
# 11      Sofa Mndez  32.0                sofa@            NaT       NaN      F
# 12     Luca Romero  29.0        lucia.romero@            NaT    3000.0      M
# 13       Pedro Nez  40.0     pedro@correo.com            NaT       NaN      M
# 14       Juan Prez  29.0      juanperez@gmail     2021-03-15    3000.0      M
# 15       Mara Lpez   NaN  m.lopez@outlook.com            NaT    4000.0      F
# 16      jose lopez  30.0  joselopez@gmail.com            NaT       NaN      M
# 17        Ana Gmez   NaN  ana_gomez@gmail.com     2021-06-01    4500.0      F
# 18    Lucas Torres  27.0                  NaN     2021-08-01    4800.0      F
# 19  Laura Fernndez  26.0     laura@correo.com            NaT       3.8      F
#
#            Comentario
# 0   Cliente frecuente
# 1   Cliente Frecuente
# 2                 NaN
# 3                 NaN
# 4   Cliente frecuente
# 5                 NaN
# 6         Cliente VIP
# 7                 NaN
# 8       Cliente nuevo
# 9                 NaN
# 10  Cliente frecuente
# 11                NaN
# 12                NaN
# 13                NaN
# 14  Cliente frecuente
# 15                NaN
# 16                NaN
# 17  Cliente Frecuente
# 18                NaN
# 19                NaN

# %% [markdown]
# ### Normalizar Nombres
#
#  Corregir la capitalización y quitar espacios extras.

# %%
df["Nombre"] = df["Nombre"].str.title().str.strip() # ! pone la primera letra en mayuscula
df.head(20)
# Out:
#             Nombre  Edad                Email Fecha_Registro  Ingresos Genero  \
# 0        Juan Prez  29.0      juanperez@gmail     2021-03-15    3000.0      M
# 1        Mara Lpez   NaN  m.lopez@outlook.com            NaT    4000.0      F
# 2       Jose Lopez   NaN           joselopez@            NaT    3500.0      M
# 3         Ana Gmez  31.0  ana_gomez@gmail.com     2021-06-01       NaN      F
# 4        Juan Prez  29.0      juanperez@gmail     2021-03-15    3000.0      M
# 5              NaN  45.0                  NaN     2021-07-12    5000.5      M
# 6     Lucas Torres  27.0   lucastorres@correo     2021-08-01    4800.0      F
# 7        Mara Lpez  30.0  m.lopez@outlook.com     2021-04-15    4000.0      F
# 8   Laura Fernndez  26.0     laura@correo.com     2021-09-01       NaN      F
# 9         Jos Lpez  30.0  joselopez@gmail.com     2021-10-10       3.6      M
# 10      Carlos Daz   NaN           carlos123@            NaT    4000.0      M
# 11      Sofa Mndez  32.0                sofa@            NaT       NaN      F
# 12     Luca Romero  29.0        lucia.romero@            NaT    3000.0      M
# 13       Pedro Nez  40.0     pedro@correo.com            NaT       NaN      M
# 14       Juan Prez  29.0      juanperez@gmail     2021-03-15    3000.0      M
# 15       Mara Lpez   NaN  m.lopez@outlook.com            NaT    4000.0      F
# 16      Jose Lopez  30.0  joselopez@gmail.com            NaT       NaN      M
# 17        Ana Gmez   NaN  ana_gomez@gmail.com     2021-06-01    4500.0      F
# 18    Lucas Torres  27.0                  NaN     2021-08-01    4800.0      F
# 19  Laura Fernndez  26.0     laura@correo.com            NaT       3.8      F
#
#            Comentario
# 0   Cliente frecuente
# 1   Cliente Frecuente
# 2                 NaN
# 3                 NaN
# 4   Cliente frecuente
# 5                 NaN
# 6         Cliente VIP
# 7                 NaN
# 8       Cliente nuevo
# 9                 NaN
# 10  Cliente frecuente
# 11                NaN
# 12                NaN
# 13                NaN
# 14  Cliente frecuente
# 15                NaN
# 16                NaN
# 17  Cliente Frecuente
# 18                NaN
# 19                NaN

# %% [markdown]
# ### Manejo de Valores Nulos
# Ahora debemos buscar los valores nulos actuales.

# %%
df.isnull().sum()
# Out:
# Nombre             1
# Edad              16
# Email              7
# Fecha_Registro    16
# Ingresos          16
# Genero             4
# Comentario        24
# dtype: int64

# %% [markdown]
# **Podriamos aplicar metodos como imputación en columnas claves, tales como en edad o ingresos**
#
# Imputar significa reemplazar datos faltantes (NaN) con un valor estimado para evitar perder información o eliminar filas completas.

# %%
df["Edad"].fillna(df["Edad"].median(), inplace=True)
df.head(20)
# Out:
# C:\Users\IPF-2025\AppData\Local\Temp\ipykernel_8196\1433257237.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Edad"].fillna(df["Edad"].median(), inplace=True)
#             Nombre  Edad                Email Fecha_Registro  Ingresos Genero  \
# 0        Juan Prez  29.0      juanperez@gmail     2021-03-15    3000.0      M
# 1        Mara Lpez  29.5  m.lopez@outlook.com            NaT    4000.0      F
# 2       Jose Lopez  29.5           joselopez@            NaT    3500.0      M
# 3         Ana Gmez  31.0  ana_gomez@gmail.com     2021-06-01       NaN      F
# 4        Juan Prez  29.0      juanperez@gmail     2021-03-15    3000.0      M
# 5              NaN  45.0                  NaN     2021-07-12    5000.5      M
# 6     Lucas Torres  27.0   lucastorres@correo     2021-08-01    4800.0      F
# 7        Mara Lpez  30.0  m.lopez@outlook.com     2021-04-15    4000.0      F
# 8   Laura Fernndez  26.0     laura@correo.com     2021-09-01       NaN      F
# 9         Jos Lpez  30.0  joselopez@gmail.com     2021-10-10       3.6      M
# 10      Carlos Daz  29.5           carlos123@            NaT    4000.0      M
# 11      Sofa Mndez  32.0                sofa@            NaT       NaN      F
# 12     Luca Romero  29.0        lucia.romero@            NaT    3000.0      M
# 13       Pedro Nez  40.0     pedro@correo.com            NaT       NaN      M
# 14       Juan Prez  29.0      juanperez@gmail     2021-03-15    3000.0      M
# 15       Mara Lpez  29.5  m.lopez@outlook.com            NaT    4000.0      F
# 16      Jose Lopez  30.0  joselopez@gmail.com            NaT       NaN      M
# 17        Ana Gmez  29.5  ana_gomez@gmail.com     2021-06-01    4500.0      F
# 18    Lucas Torres  27.0                  NaN     2021-08-01    4800.0      F
# 19  Laura Fernndez  26.0     laura@correo.com            NaT       3.8      F
#
#            Comentario
# 0   Cliente frecuente
# 1   Cliente Frecuente
# 2                 NaN
# 3                 NaN
# 4   Cliente frecuente
# 5                 NaN
# 6         Cliente VIP
# 7                 NaN
# 8       Cliente nuevo
# 9                 NaN
# 10  Cliente frecuente
# 11                NaN
# 12                NaN
# 13                NaN
# 14  Cliente frecuente
# 15                NaN
# 16                NaN
# 17  Cliente Frecuente
# 18                NaN
# 19                NaN

# %%
df["Edad"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Edad"] = df["Edad"].astype(int)
df.head()
# Out:
#        Nombre  Edad                Email Fecha_Registro  Ingresos Genero  \
# 0   Juan Prez    29      juanperez@gmail     2021-03-15    3000.0      M
# 1   Mara Lpez    29  m.lopez@outlook.com            NaT    4000.0      F
# 2  Jose Lopez    29           joselopez@            NaT    3500.0      M
# 3    Ana Gmez    31  ana_gomez@gmail.com     2021-06-01       NaN      F
# 4   Juan Prez    29      juanperez@gmail     2021-03-15    3000.0      M
#
#           Comentario
# 0  Cliente frecuente
# 1  Cliente Frecuente
# 2                NaN
# 3                NaN
# 4  Cliente frecuente

# %% [markdown]
# ¿Por qué usar la mediana?
# La mediana es resistente a valores extremos. Si tenés un dato raro como una edad de 120 años, no va a afectar tanto como afectaría el promedio.

# %%
df["Ingresos"].fillna(df["Ingresos"].mean(), inplace=True)
df.head()
# Out:
# C:\Users\IPF-2025\AppData\Local\Temp\ipykernel_8196\2650691100.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Ingresos"].fillna(df["Ingresos"].mean(), inplace=True)
#        Nombre  Edad                Email Fecha_Registro  Ingresos Genero  \
# 0   Juan Prez    29      juanperez@gmail     2021-03-15      3000      M
# 1   Mara Lpez    29  m.lopez@outlook.com            NaT      4000      F
# 2  Jose Lopez    29           joselopez@            NaT      3500      M
# 3    Ana Gmez    31  ana_gomez@gmail.com     2021-06-01      3272      F
# 4   Juan Prez    29      juanperez@gmail     2021-03-15      3000      M
#
#           Comentario
# 0  Cliente frecuente
# 1  Cliente Frecuente
# 2                NaN
# 3                NaN
# 4  Cliente frecuente

# %%
df["Ingresos"].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ¿Por qué usar la media acá?
# En ingresos, muchas veces la distribución no es tan sesgada como en edades (aunque podría serlo), así que la media es una buena primera aproximación

# %% [markdown]
# ### Matplotlib
# Matplotlib es una biblioteca de visualización de datos para el lenguaje de programación Python. Se utiliza principalmente para crear gráficos estáticos, interactivos y animados en dos dimensiones (2D), aunque tiene algunas capacidades básicas en 3D.
# Matplotlib está mayormente escrito en Python, pero también incluye componentes en C, C++ y Objective-C (para algunas partes del renderizado y para integrarse con diferentes backends gráficos como Agg, Qt, GTK, etc.).

# %% [markdown]
# ### Histograma de Edades con matplotlib
#
# Este gráfico permite ver la distribución de la edad de los clientes.
#
# Puntos a resaltar:
#
# Uso de dropna() para evitar problemas con valores faltantes.
#
# Configuración de etiquetas, título y estilo.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6, 5))
plt.hist(df["Edad"], color='skyblue', edgecolor='black')
plt.title("Distribución de edades de clientes")
plt.xlabel("Edad")
plt.ylabel("Cantidad")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Serie Temporal de Registros
# Visualizar la evolución de registros en el tiempo, usando la fecha de registro.
#
# Puntos a resaltar:
#
# Agrupar por fechas y visualizar tendencias temporales.
#
# La importancia de formatear fechas y ajustar la visualización.

# %%
registro_por_fecha = df.groupby("Fecha_Registro").size()

plt.figure(figsize=(6,5))
registro_por_fecha.plot(kind="line", marker='o', linestyle='-', color="purple")
plt.title("Evolución de Ingresos")
plt.xlabel("Fecha")
plt.ylabel("Cantidad")
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Otros Gráficos Opcionales
# Para enriquecer la clase, puedes proponer ejercicios adicionales como:
#
# Gráfico de dispersión: Relacionar Edad vs. Ingresos para ver posibles tendencias.

# %% [markdown]
# Gráfico de pastel: Proporción de clientes por género.

# %%
plt.figure(figsize=(6, 5))
plt.scatter(df["Edad"], df["Ingresos"], color='skyblue', edgecolor='black')
plt.title("Distribución de edades de clientes")
plt.xlabel("Edad")
plt.ylabel("Cantidad")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6, 5))
df["Genero"].value_counts().plot(kind="pie", autopct="%1.1f%%", startangle=90, colors=["skyblue", "red"])
plt.title("Distribución de edades de clientes")

plt.show()
